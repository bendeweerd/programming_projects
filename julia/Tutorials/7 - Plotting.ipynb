# %% [markdown]
# # Plotting
#
# ## Basics
# There are a few different ways to plot in Julia (including calling PyPlot). <br>
#
# Here we'll show you how to use `Plots.jl`.  If it's not installed yet, you need to use the package manager to install it, and Julia will precompile it for you the first time you use it:

# %%
using Pkg
Pkg.add("Plots")
using Plots
# Out:
#     Updating registry at `C:\Users\ben.m.deweerd\.julia\registries\General.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\ben.m.deweerd\.julia\environments\v1.7\Project.toml`
#   No Changes to `C:\Users\ben.m.deweerd\.julia\environments\v1.7\Manifest.toml`

# %% [markdown]
# One of the advantages to `Plots.jl` is that it allows you to seamlessly change backends. In this notebook, we'll try out the `gr()` and `plotlyjs()` backends.<br>
#
# In the name of scientific inquiry, let's use this notebook to examine the relationship between the global temperature and the number of pirates between roughly 1860 and 2000.

# %%
globaltemperatures = [14.4, 14.5, 14.8, 15.2, 15.5, 15.8]
numpirates = [45000, 20000, 15000, 5000, 400, 17];

# %% [markdown]
# Plots supports multiple backends — that is, libraries that actually do the drawing — all with the same API. To start out, let's try the GR backend.  You choose it with a call to `gr()`:

# %%
gr()
# Out:
# Plots.GRBackend()

# %% [markdown]
# and now we can use commands like `plot` and `scatter` to generate plots.

# %%
plot(numpirates, globaltemperatures, label="line")  
scatter!(numpirates, globaltemperatures, label="points")

# %% [markdown]
# The `!` at the end of the `scatter!` function name makes `scatter!` a mutating function, indicating that the scattered points will be added onto the pre-existing plot.
#
# In contrast, see what happens when you replace `scatter!` in the above with the non-mutating function `scatter`.
#
# Next, let's update this plot with the `xlabel!`, `ylabel!`, and `title!` commands to add more information to our plot.

# %%
xlabel!("Number of Pirates [Approximate]")
ylabel!("Global Temperature (C)")
title!("Influence of pirate population on global warming")

# %% [markdown]
# This still doesn't look quite right. The number of pirates has decreased since 1860, so reading the plot from left to right is like looking backwards in time rather than forwards. Let's flip the x axis to better see how pirate populations have caused global temperatures to change over time!

# %%
xflip!()

# %% [markdown]
# And there we have it!
#
# Note: We've had some confusion about this exercise. :) This is a joke about how people often conflate correlation and causation.
#
# **Without changing syntax, we can create this plot with the UnicodePlots backend**

# %%
Pkg.add("UnicodePlots")
unicodeplots()
# Out:
#    Resolving package versions...
#    Installed MarchingCubes ─────── v0.1.3
#    Installed LazyModules ───────── v0.3.0
#    Installed FreeTypeAbstraction ─ v0.9.9
#    Installed FreeType ──────────── v4.0.0
#    Installed Unitful ───────────── v1.11.0
#    Installed FileIO ────────────── v1.14.0
#    Installed CEnum ─────────────── v0.4.2
#    Installed Crayons ───────────── v4.1.1
#    Installed ConstructionBase ──── v1.3.0
#    Installed UnicodePlots ──────── v2.12.1
#     Updating `C:\Users\ben.m.deweerd\.julia\environments\v1.7\Project.toml`
#   [b8865327] + UnicodePlots v2.12.1
#     Updating `C:\Users\ben.m.deweerd\.julia\environments\v1.7\Manifest.toml`
#   [fa961155] + CEnum v0.4.2
#   [187b0558] + ConstructionBase v1.3.0
#   [a8cc5b0e] + Crayons v4.1.1
#   [5789e2e9] + FileIO v1.14.0
#   [b38be410] + FreeType v4.0.0
#   [663a7486] + FreeTypeAbstraction v0.9.9
#   [8cdb02fc] + LazyModules v0.3.0
#   [299715c1] + MarchingCubes v0.1.3
#   [b8865327] + UnicodePlots v2.12.1
#   [1986cc42] + Unitful v1.11.0
# Precompiling project...
#   ✓ LazyModules
#   ✓ ConstructionBase
#   ✓ CEnum
#   ✓ Crayons
#   ✓ MarchingCubes
#   ✓ FileIO
#   ✓ FreeType
#   ✓ FreeTypeAbstraction
#   ✓ Unitful
#   ✓ UnicodePlots
#   10 dependencies successfully precompiled in 59 seconds (134 already precompiled, 2 skipped during auto due to previous errors)
# Plots.UnicodePlotsBackend()

# %%
plot(numpirates, globaltemperatures, label="line")  
scatter!(numpirates, globaltemperatures, label="points") 
xlabel!("Number of Pirates [Approximate]")
ylabel!("Global Temperature (C)")
title!("Influence of pirate population on global warming")
# Out:
#                           Influence of pirate population on global warming
#                           ┌────────────────────────────────────────┐
#                    15.842 │⠀⚬⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│ line
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│ points
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⚬⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠑⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠈⢆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠈⚬⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#    Global Temperature (C) │⠀⡇⠀⠀⠀⠀⠈⠢⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠈⠢⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠈⠢⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⚬⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⡄⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⢢⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                           │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⚬⠤⠤⠤⢄⣀⣀⣀⣀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀│
#                    14.358 │⠀⡇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠉⠉⠉⠉⠒⠒⠒⠒⠒⠤⚬⠀│
#                           └────────────────────────────────────────┘
#                           ⠀-1332.49Number of Pirates [Approximate]46349.5⠀
# All errors:
# ===========================================
# ArgumentError: Package ImageIO [82e4d734-157c-48bb-816b-45c225c6df19] is required but does not seem to be installed:
#  - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# ===========================================
# ArgumentError: Package ImageMagick [6218d12a-5da1-5696-b52f-db25d2ecc6d1] is required but does not seem to be installed:
#  - Run `Pkg.instantiate()` to install all recorded dependencies.
#
# ===========================================
# MethodError: no method matching save(::FileIO.Stream{FileIO.DataFormat{:PNG}, IOContext{Base64.Base64EncodePipe}, Nothing}, ::Matrix{RGBA{Float32}})
# Closest candidates are:
#   save(::FileIO.File{FileIO.DataFormat{:PNG}}, ::Any) at C:\Users\ben.m.deweerd\.julia\packages\FileIO\Nl9Lh\src\mimesave.jl:5
#   save(::FileIO.File{FileIO.DataFormat{:SVG}}, ::Any) at C:\Users\ben.m.deweerd\.julia\packages\FileIO\Nl9Lh\src\mimesave.jl:15
#   save(::FileIO.File{FileIO.DataFormat{:PDF}}, ::Any) at C:\Users\ben.m.deweerd\.julia\packages\FileIO\Nl9Lh\src\mimesave.jl:25
#   ...
# ===========================================
# Errors encountered while save FileIO.Stream{FileIO.DataFormat{:PNG}, IOContext{Base64.Base64EncodePipe}, Nothing}(IOContext(Base64.Base64EncodePipe(IOBuffer(data=UInt8[...], readable=true, writable=true, seekable=true, append=false, size=0, maxsize=Inf, ptr=1, mark=-1), Base64.Buffer(UInt8[], Ptr{UInt8} @0x0000000073c59fb8, 0))), nothing).
#
# Fatal error:

# %% [markdown]
# And notice how this second plot differs from the first!  Using text like this is a little silly in a Jupyter notebook where we have fancy drawing capabilities, but it can be very useful for quick and dirty visualization in a terminal.

# %% [markdown]
# ### Exercises
#
# #### 8.1
# Given
# ```julia
# x = -10:10
# ```
# plot y vs. x for $y = x^2$.  You may want to change backends back again.

# %%
gr()

x = [i for i in -10:10]
y = [i^2 for i in x]

plot(x, y, label="line")
scatter!(x, y, label="points")
xlabel!("X")
ylabel!("X^2")

# %% [markdown]
# #### 8.2
# Execute the following code

# %%
p1 = plot(x, x)
p2 = plot(x, x.^2)
p3 = plot(x, x.^3)
p4 = plot(x, x.^4)
plot(p1, p2, p3, p4, layout = (2, 2), legend = false)

# %% [markdown]
# and then create a $4x1$ plot that uses `p1`, `p2`, `p3`, and `p4` as subplots.

# %%
gr()

plot(p1, p2, p3, p4, layout = (2, 2), legend = false)
